# %%
import pandas as pd 
import numpy as np
from pathlib import Path
import plotly.express as px

# %%
data_folder_path = Path().resolve().parent / 'DATA'

dframes ={}
# Iterate through all CSV files in the folder
for csv in data_folder_path.glob('*.csv'):
    df = pd.read_csv(csv)
    key = csv.stem
    dframes[key] = df
    
dframes.keys()
# Out:
# dict_keys(['links', 'tags', 'ratings', 'movies'])

# %%
dframes['movies']['genres'] = dframes['movies']['genres'].apply(
    lambda x: x.split('|')
)


userid_desc = dframes['ratings'].groupby('userId').agg(
    {
        'movieId':['nunique','unique'],
        'rating':['mean','std']
    }
)
userid_desc
# Out:
#        movieId                                                       rating  \
#        nunique                                             unique      mean
# userId
# 1          141  [17, 25, 29, 30, 32, 34, 36, 80, 110, 111, 161...  3.531915
# 2           52  [31, 34, 39, 48, 153, 185, 186, 193, 207, 216,...  4.269231
# 3          147  [2, 10, 11, 17, 26, 48, 62, 110, 141, 150, 151...  3.588435
# 4           27  [223, 1210, 1272, 1327, 1513, 1833, 2115, 2428...  2.629630
# 5           33  [10, 47, 110, 150, 153, 161, 165, 185, 208, 23...  3.272727
# ...        ...                                                ...       ...
# 200944     298  [1, 47, 110, 145, 165, 260, 293, 296, 318, 356...  3.947987
# 200945     108  [21, 32, 34, 36, 47, 50, 70, 215, 296, 318, 35...  3.101852
# 200946      23  [6, 10, 11, 17, 25, 36, 62, 95, 150, 161, 165,...  4.391304
# 200947      61  [1, 110, 111, 296, 318, 356, 527, 1193, 1201, ...  3.950820
# 200948     236  [1, 2, 10, 34, 39, 47, 62, 104, 110, 141, 147,...  3.595339
#
#
#              std
# userId
# 1       1.537870
# 2       1.122242
# 3       1.014789
# 4       1.043225
# 5       0.910794
# ...          ...
# 200944  0.620752
# 200945  1.901499
# 200946  0.583027
# 200947  0.650032
# 200948  1.243887
#
# [200948 rows x 4 columns]

# %%
def get_user_rated_movies(user_id: int):
    """Return titles and genres for all movies rated by the given user."""
    ratings = dframes['ratings']
    movies = dframes['movies']
    # filter ratings and merge with movie metadata
    user_ratings = ratings[ratings['userId'] == user_id]
    merged = user_ratings.merge(
        movies[['movieId','title','genres']],
        on='movieId',
        how='left'
    )
    return merged[['movieId','title','genres','rating']]

# %%
[genres[0] for genres in dframes['movies']['genres']]
# Out:
# ['Adventure',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Adventure',
#  'Action',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Children',
#  'Drama',
#  'Adventure',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Adventure',
#  'Children',
#  'Drama',
#  'Crime',
#  'Documentary',
#  'Children',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Mystery',
#  'Animation',
#  'Drama',
#  'Crime',
#  'Action',
#  'Comedy',
#  'Adventure',
#  'Children',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Children',
#  'Crime',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Children',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Documentary',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Mystery',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Adventure',
#  'Documentary',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Action',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Crime',
#  'Action',
#  'Drama',
#  'Documentary',
#  'Action',
#  'Crime',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Fantasy',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Horror',
#  'Drama',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Action',
#  'Drama',
#  'Western',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Thriller',
#  'Children',
#  'Drama',
#  'Children',
#  'Animation',
#  'Crime',
#  'Documentary',
#  'Crime',
#  'Comedy',
#  'Drama',
#  'Children',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Mystery',
#  'Adventure',
#  'Crime',
#  'Action',
#  'Drama',
#  'Children',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Action',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Animation',
#  'Children',
#  'Action',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Comedy',
#  'Film-Noir',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Horror',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Children',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Children',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Adventure',
#  'Documentary',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Thriller',
#  'Children',
#  'Drama',
#  'Action',
#  'Action',
#  'Comedy',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Western',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Crime',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Horror',
#  'Drama',
#  'Crime',
#  'Children',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Western',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Crime',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Crime',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Crime',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Horror',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Children',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Animation',
#  'Action',
#  'Action',
#  'Crime',
#  'Crime',
#  'Documentary',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Children',
#  'Comedy',
#  'Adventure',
#  'Crime',
#  'Drama',
#  'Documentary',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Children',
#  'Comedy',
#  'Adventure',
#  'Action',
#  'Adventure',
#  'Action',
#  'Action',
#  'Crime',
#  'Animation',
#  'Animation',
#  'Animation',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Comedy',
#  'Adventure',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Animation',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Thriller',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Action',
#  'Mystery',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Adventure',
#  'Comedy',
#  'Adventure',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Crime',
#  'Action',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Animation',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Film-Noir',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Children',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Comedy',
#  'War',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Fantasy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Children',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Adventure',
#  'Action',
#  'Children',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Children',
#  'Comedy',
#  'Action',
#  'Children',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Documentary',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Children',
#  'Drama',
#  'Drama',
#  'Children',
#  'Action',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Musical',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Film-Noir',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Children',
#  'Musical',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Film-Noir',
#  'Mystery',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Musical',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Children',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Musical',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Western',
#  'Horror',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Mystery',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Documentary',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Action',
#  'Crime',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Children',
#  'Drama',
#  'Children',
#  'Adventure',
#  'Adventure',
#  'Children',
#  'Children',
#  'Children',
#  'Children',
#  'Children',
#  'Adventure',
#  'Children',
#  'Adventure',
#  'Children',
#  'Adventure',
#  'Comedy',
#  'Children',
#  'Animation',
#  ...]
